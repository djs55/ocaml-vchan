# %%
open Vchan

# %%
module V = Vchan.In_memory

# %%
let port = Vchan.Port.of_string "myport" with
  | `Error _ -> invalid_arg "Vchan.Port.of_string"
  | `Ok x -> x

# %%
let server_thread = V.server ~domid:1 ~port ()

# %%
let client_thread = V.client ~domid:1 ~port ()
